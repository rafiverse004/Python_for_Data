# %% [markdown]
# A list is a collection of multiple values in one variable.
#
#     numbers = [10, 20, 30, 40]
#
# You can store:
#
#     numbers
#     strings
#     mixed data -> data = [10, "hello", 3.5, True]
#
# Indexing (access items)
#
# Negative Indexing (access items)
#
# Slicing (get part of list)
#
# Add items
#
# Remove items
#
# Change value
#
# Length of list
#
# Loop through list
