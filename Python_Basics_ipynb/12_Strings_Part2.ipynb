# %% [markdown]
# Methods are built-in functions for strings.
#
#     upper()
#
# Converts to uppercase
#
#     lower()
#
# Converts to lowercase
#
#     strip()
#
# Removes extra spaces (start/end only)
#
#     replace()
#
# Replaces text
#
#     split()
#
# Breaks string into list
