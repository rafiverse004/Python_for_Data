# %% [markdown]
# 🧠What is a dictionary?
#
# A dictionary stores data in key → value pairs
#
# student = {
#     "name": "Rafik",
#     "age": 20,
#     "grade": "A"
# }
#
# Access values
#
# Add / Update values
#
# Remove items
#
# Get keys, values
#
# Loop through dictionary (keys only)
#
# Loop through dictionary (keys + value)
