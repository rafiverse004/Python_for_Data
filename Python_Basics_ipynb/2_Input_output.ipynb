# %% [markdown]
#     input()
#
# Used to take input from the user
#
#     print()
#
# Used to display output on the screen
#
#     Formatting Output (f-string)
#
# Used to insert variables inside a string.
